# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
cd = pd.read_excel('train_CustomerDemographic.xlsx')
cd.head()
# Out:
#    customer_id  gender job_industry_category     wealth_segment  \
# 0            1  Female                Health      Mass Customer
# 1            2    Male    Financial Services      Mass Customer
# 2            3    Male              Property      Mass Customer
# 3            4    Male                    IT      Mass Customer
# 4            5  Female    Financial Services  Affluent Customer
#
#   deceased_indicator owns_car customer_current_age
# 0                  N      Yes                   70
# 1                  N      Yes                   43
# 2                  N      Yes                   69
# 3                  N       No                   62
# 4                  N      Yes                   46

# %%
ca = pd.read_excel('train_CustomerAddress.xlsx')
ca.head()
# Out:
#    customer_id              address state    country
# 0            1   060 Morning Avenue   NSW  Australia
# 1            2  6 Meadow Vale Court   NSW  Australia
# 2            4   0 Holy Cross Court   QLD  Australia
# 3            5  17979 Del Mar Point   NSW  Australia
# 4            6     9 Oakridge Court   VIC  Australia

# %%
trans = pd.read_excel('train_transaction.xlsx')
trans.head()
# Out:
#    transaction_id  product_id  customer_id  online_order order_status  \
# 0               1           2         2950             0     Approved
# 1               2           3         3120             1     Approved
# 2               3          37          402             0     Approved
# 3               4          88         3135             0     Approved
# 4               5          78          787             1     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost transactions_month
# 0          53.62           February
# 1         388.92                May
# ...

# %%
cd.isnull().sum()
# Out:
# customer_id              0
# gender                   0
# job_industry_category    0
# wealth_segment           0
# deceased_indicator       0
# owns_car                 0
# customer_current_age     0
# dtype: int64

# %%
ca.isnull().sum()
# Out:
# customer_id    0
# address        0
# state          0
# country        0
# dtype: int64

# %%
trans.isnull().sum()
# Out:
# transaction_id        0
# product_id            0
# customer_id           0
# online_order          0
# order_status          0
# brand                 0
# product_line          0
# product_class         0
# product_size          0
# list_price            0
# standard_cost         0
# transactions_month    0
# dtype: int64

# %%
print(cd.shape)
print(ca.shape)
print(trans.shape)
# Out:
# (4000, 7)
# (3999, 4)
# (19445, 12)

# %%
df = trans.merge(cd, left_on=trans['customer_id'], right_on = cd['customer_id'])
df
# Out:
#        key_0  transaction_id  product_id  customer_id_x  online_order  \
# 0       2950               1           2           2950             0
# 1       2950           11065           1           2950             0
# 2       2950           18923          62           2950             0
# 3       3120               2           3           3120             1
# 4       3120            6862           4           3120             0
# ...      ...             ...         ...            ...           ...
# 19437   2764           19999           6           2764             0
# 19438   3168           18735          45           3168             1
# 19439   3168           18789          83           3168             0
# 19440   3168           19113           3           3168             0
# 19441   3168           19912           3           3168             0
#
#       order_status           brand product_line product_class product_size  \
# ...

# %%
df = cd.merge(ca, left_on='customer_id', right_on='customer_id')

# %%
df.shape
# Out:
# (3996, 10)

# %%
df = df.merge(trans, left_on='customer_id', right_on='customer_id')

# %%
df.shape
# Out:
# (19416, 21)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'job_industry_category', 'wealth_segment',
#        'deceased_indicator', 'owns_car', 'customer_current_age', 'address',
#        'state', 'country', 'transaction_id', 'product_id', 'online_order',
#        'order_status', 'brand', 'product_line', 'product_class',
#        'product_size', 'list_price', 'standard_cost', 'transactions_month'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# customer_id              0
# gender                   0
# job_industry_category    0
# wealth_segment           0
# deceased_indicator       0
# owns_car                 0
# customer_current_age     0
# address                  0
# state                    0
# country                  0
# transaction_id           0
# product_id               0
# online_order             0
# order_status             0
# brand                    0
# product_line             0
# product_class            0
# product_size             0
# list_price               0
# standard_cost            0
# transactions_month       0
# dtype: int64

# %%
df.to_excel('train_sprocket.xlsx', index=None)

# %%
df = pd.read_excel('train_sprocket.xlsx')
df
# Out:
#        customer_id  gender job_industry_category     wealth_segment  \
# 0                1  Female                Health      Mass Customer
# 1                1  Female                Health      Mass Customer
# 2                1  Female                Health      Mass Customer
# 3                1  Female                Health      Mass Customer
# 4                1  Female                Health      Mass Customer
# ...            ...     ...                   ...                ...
# 19411         3500  Female         Entertainment  Affluent Customer
# 19412         3500  Female         Entertainment  Affluent Customer
# 19413         3500  Female         Entertainment  Affluent Customer
# 19414         3500  Female         Entertainment  Affluent Customer
# 19415         3500  Female         Entertainment  Affluent Customer
#
#       deceased_indicator owns_car customer_current_age  \
# 0                      N      Yes                   70
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19416 entries, 0 to 19415
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            19416 non-null  int64
#  1   gender                 19416 non-null  object
#  2   job_industry_category  19416 non-null  object
#  3   wealth_segment         19416 non-null  object
#  4   deceased_indicator     19416 non-null  object
#  5   owns_car               19416 non-null  object
#  6   customer_current_age   19416 non-null  object
#  7   address                19416 non-null  object
#  8   state                  19416 non-null  object
#  9   country                19416 non-null  object
#  10  transaction_id         19416 non-null  int64
#  11  product_id             19416 non-null  int64
#  12  online_order           19416 non-null  int64
#  13  order_status           19416 non-null  object
# ...

# %%
cd['customer_current_age']
# Out:
# 0                       70
# 1                       43
# 2                       69
# 3                       62
# 4                       46
#                ...
# 3995                    48
# 3996                    22
# 3997    Financial Services
# 3998                    50
# 3999                    32
# Name: customer_current_age, Length: 4000, dtype: object
